# %% [markdown]
# # Notebook 4
#
# - If you work on Google Colab, [![open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](
# https://colab.research.google.com/github/jouvetg/glamod/blob/main/04_notebook/glacier-modelling-4.ipynb) and you will donwload the repo  below. Make sure to activate the GPU on Colab "Runtime" -> "Change Runtime Type" -> Slect GPU.
#
# - If you work locally on your own PC, you can download the repo
# ```bash
# git clone --depth 1 https://github.com/jouvetg/glamod.git
# ```
# and then go the notebook folder, and work from there.

# %% [markdown]
# ## How to install IGM?
#
# Running IGM consists of running a python script `igm_run`, which is made of functions of the `igm` python package.  First of all, one needs to install igm as follows: (this may take a while, and it may crashes the first time, but should work the second time).

# %%
! pip install -i https://test.pypi.org/simple/ --extra-index-url https://pypi.org/simple igm-model-testing-package==3.0.5
! pip install ml-dtypes==0.5.3
# Out:
# Looking in indexes: https://test.pypi.org/simple/, https://pypi.org/simple
# Collecting igm-model-testing-package==3.0.5
#   Downloading https://test-files.pythonhosted.org/packages/c5/c2/f82e8d7a85ea222215053ecd0bf1e3206fb637572f66a6225fc48c71cbbd/igm_model_testing_package-3.0.5-py3-none-any.whl.metadata (3.4 kB)
# Collecting tensorflow==2.17.1 (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5)
#   Downloading tensorflow-2.17.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (1.16.3)
# Collecting netCDF4==1.6.0 (from igm-model-testing-package==3.0.5)
#   Downloading netCDF4-1.6.0.tar.gz (774 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.2/774.2 kB 22.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (2025.11.0)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (1.4.3)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (3.7.2)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (1.1.1)
# Collecting oggm (from igm-model-testing-package==3.0.5)
#   Downloading oggm-1.6.2-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting salem (from igm-model-testing-package==3.0.5)
#   Downloading salem-0.3.11-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (6.0.3)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (6.5.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (4.67.1)
# Collecting hydra-core (from igm-model-testing-package==3.0.5)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from igm-model-testing-package==3.0.5) (2.3.0)
# Requirement already satisfied: numpy>=1.9 in /usr/local/lib/python3.12/dist-packages (from netCDF4==1.6.0->igm-model-testing-package==3.0.5) (2.0.2)
# Collecting cftime (from netCDF4==1.6.0->igm-model-testing-package==3.0.5)
#   Downloading cftime-1.6.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.15.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (18.1.1)
# Collecting ml-dtypes<0.5.0,>=0.3.1 (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5)
#   Downloading ml_dtypes-0.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (25.0)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5)
#   Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (1.76.0)
# Collecting tensorboard<2.18,>=2.17 (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5)
#   Downloading tensorboard-2.17.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.10.0)
# Collecting numpy>=1.9 (from netCDF4==1.6.0->igm-model-testing-package==3.0.5)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.6 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.3.4.1 (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5)
#   Downloading nvidia_cublas_cu12-12.3.4.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.3.101 (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5)
#   Downloading nvidia_cuda_cupti_cu12-12.3.101-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-nvcc-cu12==12.3.107 (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5)
#   Downloading nvidia_cuda_nvcc_cu12-12.3.107-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.3.107 (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5)
#   Downloading nvidia_cuda_nvrtc_cu12-12.3.107-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.3.101 (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5)
#   Downloading nvidia_cuda_runtime_cu12-12.3.101-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cudnn-cu12==8.9.7.29 (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5)
#   Downloading nvidia_cudnn_cu12-8.9.7.29-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cufft-cu12==11.0.12.1 (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5)
#   Downloading nvidia_cufft_cu12-11.0.12.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.4.107 (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5)
#   Downloading nvidia_curand_cu12-10.3.4.107-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.5.4.101 (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5)
#   Downloading nvidia_cusolver_cu12-11.5.4.101-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.2.0.103 (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5)
#   Downloading nvidia_cusparse_cu12-12.2.0.103-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.19.3 (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5)
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.3.101 (from tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5)
#   Downloading nvidia_nvjitlink_cu12-12.3.101-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas->igm-model-testing-package==3.0.5) (0.11.1)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->igm-model-testing-package==3.0.5) (2.2.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->igm-model-testing-package==3.0.5) (2.1.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj->igm-model-testing-package==3.0.5) (2025.11.12)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core->igm-model-testing-package==3.0.5) (4.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->igm-model-testing-package==3.0.5) (2.9.0.post0)
# Collecting configobj (from oggm->igm-model-testing-package==3.0.5)
#   Downloading configobj-5.0.9-py2.py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio->igm-model-testing-package==3.0.5) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio->igm-model-testing-package==3.0.5) (25.4.0)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio->igm-model-testing-package==3.0.5) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio->igm-model-testing-package==3.0.5) (0.7.2)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.12/dist-packages (from rasterio->igm-model-testing-package==3.0.5) (1.1.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from salem->igm-model-testing-package==3.0.5) (1.5.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.18.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas->igm-model-testing-package==3.0.5) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas->igm-model-testing-package==3.0.5) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.5.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard<2.18,>=2.17->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow==2.17.1->tensorflow[and-cuda]==2.17.1->igm-model-testing-package==3.0.5) (0.1.2)
# Downloading https://test-files.pythonhosted.org/packages/c5/c2/f82e8d7a85ea222215053ecd0bf1e3206fb637572f66a6225fc48c71cbbd/igm_model_testing_package-3.0.5-py3-none-any.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 30.6 MB/s eta 0:00:00
# Downloading tensorflow-2.17.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (601.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 601.4/601.4 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.3.4.1-py3-none-manylinux1_x86_64.whl (412.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.6/412.6 MB 1.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.3.101-py3-none-manylinux1_x86_64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 104.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvcc_cu12-12.3.107-py3-none-manylinux1_x86_64.whl (22.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.0/22.0 MB 109.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.3.107-py3-none-manylinux1_x86_64.whl (24.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 76.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.3.101-py3-none-manylinux1_x86_64.whl (867 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 867.7/867.7 kB 65.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.7.29-py3-none-manylinux1_x86_64.whl (704.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 704.7/704.7 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.12.1-py3-none-manylinux1_x86_64.whl (98.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.8/98.8 MB 8.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.4.107-py3-none-manylinux1_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.5.4.101-py3-none-manylinux1_x86_64.whl (125.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.2.0.103-py3-none-manylinux1_x86_64.whl (197.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.5/197.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.3.101-py3-none-manylinux1_x86_64.whl (20.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 77.7 MB/s eta 0:00:00
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 16.4 MB/s eta 0:00:00
# Downloading oggm-1.6.2-py2.py3-none-any.whl (463 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 463.4/463.4 kB 41.2 MB/s eta 0:00:00
# Downloading salem-0.3.11-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.1/86.1 kB 6.5 MB/s eta 0:00:00
# Downloading ml_dtypes-0.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 92.9 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 109.7 MB/s eta 0:00:00
# Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 32.1 MB/s eta 0:00:00
# Downloading tensorboard-2.17.1-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 127.5 MB/s eta 0:00:00
# Downloading cftime-1.6.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 98.4 MB/s eta 0:00:00
# Downloading configobj-5.0.9-py2.py3-none-any.whl (35 kB)
# Building wheels for collected packages: netCDF4
#   Building wheel for netCDF4 (setup.py) ... done
#   Created wheel for netCDF4: filename=netCDF4-1.6.0-cp312-cp312-linux_x86_64.whl size=2913318 sha256=df7449756883340295a466ad22adf7f8bfd19fe672b23639415d4b0be6ea780b
#   Stored in directory: /root/.cache/pip/wheels/8c/85/25/5408d84c4ee21638dda70b1dbbd87d4148d6815d16032b9377
# Successfully built netCDF4
# Installing collected packages: protobuf, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-nvcc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, configobj, tensorboard, nvidia-cusparse-cu12, nvidia-cudnn-cu12, ml-dtypes, hydra-core, cftime, nvidia-cusolver-cu12, netCDF4, tensorflow, salem, oggm, igm-model-testing-package
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.6.85
#     Uninstalling nvidia-nvjitlink-cu12-12.6.85:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.6.85
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.5
#     Uninstalling nvidia-nccl-cu12-2.27.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.5
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.6.77
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-nvcc-cu12
#     Found existing installation: nvidia-cuda-nvcc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvcc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvcc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.4.1
#     Uninstalling nvidia-cublas-cu12-12.6.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.4.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.19.0
#     Uninstalling tensorboard-2.19.0:
#       Successfully uninstalled tensorboard-2.19.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml_dtypes 0.5.4
#     Uninstalling ml_dtypes-0.5.4:
#       Successfully uninstalled ml_dtypes-0.5.4
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.1.2
#     Uninstalling nvidia-cusolver-cu12-11.7.1.2:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.1.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.19.0
#     Uninstalling tensorflow-2.19.0:
#       Successfully uninstalled tensorflow-2.19.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorstore 0.1.79 requires ml_dtypes>=0.5.0, but you have ml-dtypes 0.4.1 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.8 which is incompatible.
# tensorflow-decision-forests 1.12.0 requires tensorflow==2.19.0, but you have tensorflow 2.17.1 which is incompatible.
# jax 0.7.2 requires ml_dtypes>=0.5.0, but you have ml-dtypes 0.4.1 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# torch 2.9.0+cu126 requires nvidia-cublas-cu12==12.6.4.1; platform_system == "Linux", but you have nvidia-cublas-cu12 12.3.4.1 which is incompatible.
# torch 2.9.0+cu126 requires nvidia-cuda-cupti-cu12==12.6.80; platform_system == "Linux", but you have nvidia-cuda-cupti-cu12 12.3.101 which is incompatible.
# torch 2.9.0+cu126 requires nvidia-cuda-nvrtc-cu12==12.6.77; platform_system == "Linux", but you have nvidia-cuda-nvrtc-cu12 12.3.107 which is incompatible.
# torch 2.9.0+cu126 requires nvidia-cuda-runtime-cu12==12.6.77; platform_system == "Linux", but you have nvidia-cuda-runtime-cu12 12.3.101 which is incompatible.
# torch 2.9.0+cu126 requires nvidia-cudnn-cu12==9.10.2.21; platform_system == "Linux", but you have nvidia-cudnn-cu12 8.9.7.29 which is incompatible.
# torch 2.9.0+cu126 requires nvidia-cufft-cu12==11.3.0.4; platform_system == "Linux", but you have nvidia-cufft-cu12 11.0.12.1 which is incompatible.
# torch 2.9.0+cu126 requires nvidia-curand-cu12==10.3.7.77; platform_system == "Linux", but you have nvidia-curand-cu12 10.3.4.107 which is incompatible.
# torch 2.9.0+cu126 requires nvidia-cusolver-cu12==11.7.1.2; platform_system == "Linux", but you have nvidia-cusolver-cu12 11.5.4.101 which is incompatible.
# torch 2.9.0+cu126 requires nvidia-cusparse-cu12==12.5.4.2; platform_system == "Linux", but you have nvidia-cusparse-cu12 12.2.0.103 which is incompatible.
# torch 2.9.0+cu126 requires nvidia-nccl-cu12==2.27.5; platform_system == "Linux", but you have nvidia-nccl-cu12 2.19.3 which is incompatible.
# torch 2.9.0+cu126 requires nvidia-nvjitlink-cu12==12.6.85; platform_system == "Linux", but you have nvidia-nvjitlink-cu12 12.3.101 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tensorflow-text 2.19.0 requires tensorflow<2.20,>=2.19.0, but you have tensorflow 2.17.1 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tf-keras 2.19.0 requires tensorflow<2.20,>=2.19, but you have tensorflow 2.17.1 which is incompatible.
# pytensor 2.35.1 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.8 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opentelemetry-proto 1.37.0 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.8 which is incompatible.
# jaxlib 0.7.2 requires ml_dtypes>=0.5.0, but you have ml-dtypes 0.4.1 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# Successfully installed cftime-1.6.5 configobj-5.0.9 hydra-core-1.3.2 igm-model-testing-package-3.0.5 ml-dtypes-0.4.1 netCDF4-1.6.0 numpy-1.26.4 nvidia-cublas-cu12-12.3.4.1 nvidia-cuda-cupti-cu12-12.3.101 nvidia-cuda-nvcc-cu12-12.3.107 nvidia-cuda-nvrtc-cu12-12.3.107 nvidia-cuda-runtime-cu12-12.3.101 nvidia-cudnn-cu12-8.9.7.29 nvidia-cufft-cu12-11.0.12.1 nvidia-curand-cu12-10.3.4.107 nvidia-cusolver-cu12-11.5.4.101 nvidia-cusparse-cu12-12.2.0.103 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.3.101 oggm-1.6.2 protobuf-4.25.8 salem-0.3.11 tensorboard-2.17.1 tensorflow-2.17.1
# Collecting ml-dtypes==0.5.3
#   Downloading ml_dtypes-0.5.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.12/dist-packages (from ml-dtypes==0.5.3) (1.26.4)
# Downloading ml_dtypes-0.5.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 114.4 MB/s eta 0:00:00
# Installing collected packages: ml-dtypes
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.1 requires ml-dtypes<0.5.0,>=0.3.1, but you have ml-dtypes 0.5.3 which is incompatible.
# tensorflow-decision-forests 1.12.0 requires tensorflow==2.19.0, but you have tensorflow 2.17.1 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tensorflow-text 2.19.0 requires tensorflow<2.20,>=2.19.0, but you have tensorflow 2.17.1 which is incompatible.
# tf-keras 2.19.0 requires tensorflow<2.20,>=2.19, but you have tensorflow 2.17.1 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed ml-dtypes-0.5.3

# %% [markdown]
# ## Download the data

# %% [markdown]
# Let's now download the repo with the data if you are using Colab

# %%
import sys, os

if "google.colab" in sys.modules:
    print("Running in Colab: cloning repo...")
    # !git clone --depth 1 https://github.com/jouvetg/glamod.git
    # !apt-get install tree -q
else:
    print("Running locally: using local files.")
# Out:
# Running in Colab: cloning repo...
# Cloning into 'glamod'...
# remote: Enumerating objects: 81, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 81 (delta 10), reused 57 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (81/81), 14.05 MiB | 9.01 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   tree
# 0 upgraded, 1 newly installed, 0 to remove and 41 not upgraded.
# Need to get 47.9 kB of archives.
# After this operation, 116 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tree amd64 2.0.2-1 [47.9 kB]
# Fetched 47.9 kB in 1s (53.2 kB/s)
# Selecting previously unselected package tree.
# (Reading database ... 121713 files and directories currently installed.)
# Preparing to unpack .../tree_2.0.2-1_amd64.deb ...
# Unpacking tree (2.0.2-1) ...
# Setting up tree (2.0.2-1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %% [markdown]
# Let's now go the working folder

# %%
if "google.colab" in sys.modules:
    # %cd /content/glamod/04_notebook
# Out:
# /content/glamod/04_notebook

# %% [markdown]
# # Modelling Glacier du Mont Miné
#
# In this notebook we aim to model the evolution of "[Glacier du Mont Miné](https://www.google.com/maps/place/Mont+Min%C3%A9+Glacier/@46.0145075,7.4877889,24811m/data=!3m1!1e3!4m6!3m5!1s0x478f2db4b5d1a731:0x2c7d28e4d7f7bb26!8m2!3d46.014!4d7.54439!16s%2Fm%2F04n61lb?entry=ttu&g_ep=EgoyMDI0MTAyNy4wIKXMDSoASAFQAw%3D%3D,)" located in te South of Sion (Valais, Switzerland), from the end of the little ice age (about 1850) to now, the goal being to calibrate the glacier model to match the OSL data. To this aim, we take over the material from the previous notebook, and apply it Mont Miné.
#
# You may find on slides 28 to 30 some graphical [illustrations](https://www.unige.ch/forel/application/files/3116/5476/6042/F-Evolene-Paysagesglaciaires_compressed.pdf) of the retreat of the Mont Miné Glacier since the end of the Little Ice Age (LIA).

# %% [markdown]
# Running `igm_run +experiment=params` will  collect the data, run the model forward in time from 1700 to 2024 with a rather simple surface mass balance parametrized by the equilibrium line altitude, and save the output in a netCDF file `output.nc`.

# %%
! igm_run +experiment=params
# Out:
# 2025-12-02 10:04:45.039773: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-12-02 10:04:45.060118: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-12-02 10:04:45.066428: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-12-02 10:04:45.081929: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-02 10:04:47.722476: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764669890.733779   27419 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1764669890.785841   27419 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1764669890.786175   27419 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# -------------------------------------------------------------------CUDA Enviroment--------------------------------------------------------------------
# {
#   "cpu_compiler": "/usr/lib/llvm-17/bin/clang",
#   "cuda_version": "12.3",
#   "cudnn_version": "8",
#   "is_cuda_build": true,
#   "is_rocm_build": false,
#   "is_tensorrt_build": true
# }
# ----------------------------------------------------------------Available GPU Devices-----------------------------------------------------------------
# I0000 00:00:1764669890.786690   27419 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# {
#   "gpu_id": "/physical_device:GPU:0",
#   "device_type": "GPU",
#   "compute_capability": [
#     7,
#     5
#   ],
#   "device_name": "Tesla T4"
# }
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# I0000 00:00:1764669890.787745   27419 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1764669890.787998   27419 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1764669890.788198   27419 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1764669890.876915   27419 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1764669890.877268   27419 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1764669890.877531   27419 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-12-02 10:04:50.877698: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 1 Physical GPUs, 1 Logical GPU
# ----------------------------------------------------------------------------------------------------
# -------------------------------------------INPUTS Modules-------------------------------------------
#  0: <module 'igm.inputs.oggm_shop' from '/usr/local/lib/python3.12/dist-packages/igm/inputs/oggm_shop/__init__.py'>
#  1: <module 'igm.inputs.local' from '/usr/local/lib/python3.12/dist-packages/igm/inputs/local.py'>
# -----------------------------------------PROCESSES Modules------------------------------------------
#  0: <module 'igm.processes.smb_simple' from '/usr/local/lib/python3.12/dist-packages/igm/processes/smb_simple/__init__.py'>
#  1: <module 'igm.processes.iceflow' from '/usr/local/lib/python3.12/dist-packages/igm/processes/iceflow/__init__.py'>
#  2: <module 'igm.processes.time' from '/usr/local/lib/python3.12/dist-packages/igm/processes/time/__init__.py'>
#  3: <module 'igm.processes.thk' from '/usr/local/lib/python3.12/dist-packages/igm/processes/thk/__init__.py'>
# ------------------------------------------OUTPUTS Modules-------------------------------------------
#  0: <module 'igm.outputs.local' from '/usr/local/lib/python3.12/dist-packages/igm/outputs/local.py'>
#  1: <module 'igm.outputs.plot2d' from '/usr/local/lib/python3.12/dist-packages/igm/outputs/plot2d.py'>
# ----------------------------------------------------------------------------------------------------
# Found pretrained emulator in the igm package: pinnbp_10_4_cnn_16_32_2_1_a
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Model: "model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_1             │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 5)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, None,      │      1,472 │ input_1[0][0]     │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ leaky_re_lu         │ (None, None,      │          0 │ conv2d[0][0],     │
# │ (LeakyReLU)         │ None, 32)         │            │ conv2d_1[0][0],   │
# │                     │                   │            │ conv2d_2[0][0],   │
# │                     │                   │            │ conv2d_3[0][0],   │
# │                     │                   │            │ conv2d_4[0][0],   │
# │                     │                   │            │ conv2d_5[0][0],   │
# │                     │                   │            │ conv2d_6[0][0],   │
# │                     │                   │            │ conv2d_7[0][0],   │
# │                     │                   │            │ conv2d_8[0][0],   │
# │                     │                   │            │ conv2d_9[0][0],   │
# │                     │                   │            │ conv2d_10[0][0],  │
# │                     │                   │            │ conv2d_11[0][0],  │
# │                     │                   │            │ conv2d_12[0][0],  │
# │                     │                   │            │ conv2d_13[0][0],  │
# │                     │                   │            │ conv2d_14[0][0],  │
# │                     │                   │            │ conv2d_15[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, None,      │          0 │ leaky_re_lu[0][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, None,      │      9,248 │ dropout[0][0]     │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[1][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, None,      │      9,248 │ dropout_1[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[2][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, None,      │      9,248 │ dropout_2[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[3][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, None,      │      9,248 │ dropout_3[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[4][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, None,      │      9,248 │ dropout_4[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[5][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, None,      │      9,248 │ dropout_5[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[6][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, None,      │      9,248 │ dropout_6[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[7][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, None,      │      9,248 │ dropout_7[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[8][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, None,      │      9,248 │ dropout_8[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, None,      │          0 │ leaky_re_lu[9][0] │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, None,      │      9,248 │ dropout_9[0][0]   │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_10          │ (None, None,      │          0 │ leaky_re_lu[10][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, None,      │      9,248 │ dropout_10[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_11          │ (None, None,      │          0 │ leaky_re_lu[11][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, None,      │      9,248 │ dropout_11[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_12          │ (None, None,      │          0 │ leaky_re_lu[12][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, None,      │      9,248 │ dropout_12[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, None,      │          0 │ leaky_re_lu[13][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, None,      │      9,248 │ dropout_13[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, None,      │          0 │ leaky_re_lu[14][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, None,      │      9,248 │ dropout_14[0][0]  │
# │                     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_15          │ (None, None,      │          0 │ leaky_re_lu[15][… │
# │ (Dropout)           │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, None,      │        660 │ dropout_15[0][0]  │
# │                     │ None, 20)         │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 140,852 (550.20 KB)
#  Trainable params: 140,852 (550.20 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# 2025-12-02 10:04:53.021141: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# W0000 00:00:1764669893.096422   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.148989   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.150166   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.156703   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.157922   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.159086   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.160225   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.161431   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.162626   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.164062   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.165251   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.168031   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.169228   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.170442   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.173170   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.187475   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.200757   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.232259   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.233474   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.234744   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.236009   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.237212   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.238420   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.239626   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.252876   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.254197   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.255550   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.256902   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.258363   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.259637   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.260998   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.262383   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.263899   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.265582   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669893.271429   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/tensor_util.py:522: RuntimeWarning: overflow encountered in cast
#   nparray = np.array(values, dtype=np_dt)
# W0000 00:00:1764669901.167356   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.168588   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.169915   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.176734   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.178168   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.179648   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.181069   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.182500   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.184233   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.185891   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.205040   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.208841   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.236017   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.238091   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.240282   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.241636   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.244623   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.249169   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.251772   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.253548   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.255167   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.257991   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.259882   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.263463   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.267372   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.292864   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.294099   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.295395   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.296809   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.298013   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.299199   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.300378   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.301940   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.303382   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.304704   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.312236   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.315246   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.316427   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.317725   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.318925   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.320178   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.321559   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.322880   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.324629   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.326731   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# W0000 00:00:1764669901.329536   27419 gpu_timer.cc:114] Skipping the delay kernel, measurement accuracy will be reduced
# IGM , 🕒=10:05:14, 🔄=000100, ⏱ Time=0001732.6 yr, ⏳ Step=0.19 yr, ❄️  Volume=1.16 km³
# IGM , 🕒=10:05:24, 🔄=000200, ⏱ Time=0001750.0 yr, ⏳ Step=0.02 yr, ❄️  Volume=1.33 km³
# IGM , 🕒=10:05:33, 🔄=000300, ⏱ Time=0001765.6 yr, ⏳ Step=0.15 yr, ❄️  Volume=1.44 km³
# IGM , 🕒=10:05:45, 🔄=000400, ⏱ Time=0001780.8 yr, ⏳ Step=0.15 yr, ❄️  Volume=1.51 km³
# IGM , 🕒=10:05:53, 🔄=000500, ⏱ Time=0001795.9 yr, ⏳ Step=0.15 yr, ❄️  Volume=1.55 km³
# IGM , 🕒=10:06:05, 🔄=000600, ⏱ Time=0001811.2 yr, ⏳ Step=0.16 yr, ❄️  Volume=1.57 km³
# IGM , 🕒=10:06:15, 🔄=000700, ⏱ Time=0001826.7 yr, ⏳ Step=0.16 yr, ❄️  Volume=1.57 km³
# IGM , 🕒=10:06:27, 🔄=000800, ⏱ Time=0001842.0 yr, ⏳ Step=0.16 yr, ❄️  Volume=1.58 km³
# IGM , 🕒=10:06:38, 🔄=000900, ⏱ Time=0001857.7 yr, ⏳ Step=0.16 yr, ❄️  Volume=1.57 km³
# IGM , 🕒=10:06:50, 🔄=001000, ⏱ Time=0001873.5 yr, ⏳ Step=0.16 yr, ❄️  Volume=1.55 km³
# IGM , 🕒=10:07:01, 🔄=001100, ⏱ Time=0001890.0 yr, ⏳ Step=0.17 yr, ❄️  Volume=1.50 km³
# IGM , 🕒=10:07:15, 🔄=001200, ⏱ Time=0001907.0 yr, ⏳ Step=0.18 yr, ❄️  Volume=1.44 km³
# IGM , 🕒=10:07:29, 🔄=001300, ⏱ Time=0001924.9 yr, ⏳ Step=0.18 yr, ❄️  Volume=1.38 km³
# IGM , 🕒=10:07:43, 🔄=001400, ⏱ Time=0001943.5 yr, ⏳ Step=0.19 yr, ❄️  Volume=1.33 km³
# IGM , 🕒=10:07:57, 🔄=001500, ⏱ Time=0001963.1 yr, ⏳ Step=0.20 yr, ❄️  Volume=1.28 km³
# IGM , 🕒=10:08:12, 🔄=001600, ⏱ Time=0001984.2 yr, ⏳ Step=0.22 yr, ❄️  Volume=1.23 km³
# IGM , 🕒=10:08:28, 🔄=001700, ⏱ Time=0002007.2 yr, ⏳ Step=0.24 yr, ❄️  Volume=1.17 km³
# IGM , 🕒=10:08:46, 🔄=001769, ⏱ Time=0002024.0 yr, ⏳ Step=0.19 yr, ❄️  Volume=1.14 km³

# %% [markdown]
# Explore `params.yaml` to see the details of the configuration. A closer look at the parameter file shows that we declare some physical modules, such as `smb_simple`, `iceflow`, `time`, and `thk`.
#
# The first module `smb_simple` computes the surface mass balance as $SMB(z) = \alpha (z - z_{ELA})$, with one SMB gradient $\beta_{abl}$ in the ablation area when $z < z_{ELA}$, and one SMB gradient $\beta_{acc}$ in the accumulation area when $z > z_{ELA}$, along with a maximum SMB capping value of $a_{max}$, as illustrated in the following figure:

# %%
import numpy as np
import matplotlib.pyplot as plt

def surface_mass_balance(z, z_ELA, beta_abl, beta_acc, a_max):
    smb = np.zeros_like(z)
    smb[z < z_ELA] = beta_abl * (z[z < z_ELA] - z_ELA)
    smb[z > z_ELA] = beta_acc * (z[z > z_ELA] - z_ELA)
    smb[smb > a_max] = a_max
    return smb

z = np.linspace(1000, 4000, 100)
smb_values = surface_mass_balance(z, z_ELA= 3000, beta_abl= 0.005, beta_acc= 0.002, a_max= 1.0)

plt.figure(figsize=(10, 6))
plt.plot(z, smb_values, label='Surface Mass Balance (SMB)', color='blue')
plt.axhline(0, color='grey', linestyle='--', linewidth=0.8)  # Line at 0
plt.axvline(3000, color='red', linestyle='--', label='ELA (z_ELA)', linewidth=1)  # ELA line
plt.title('Surface Mass Balance as a Function of Elevation')
plt.xlabel('Elevation (m)')
plt.ylabel('Surface Mass Balance (SMB)')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# In `params.yaml`, the SMB parameters are evolving with time as follows:
#
# ```yaml
#       - ["time", "gradabl", "gradacc", "ela", "accmax"]
#       - [ 1700,      0.009,     0.005,  2850,      2.0]
#       - [ 1800,      0.009,     0.005,  2900,      2.0]
#       - [ 1850,      0.009,     0.005,  2900,      2.0]
#       - [ 1900,      0.009,     0.005,  3000,      2.0]
#       - [ 2000,      0.009,     0.005,  3100,      2.0]
#       - [ 2024,      0.009,     0.005,  3100,      2.0]
# ```
# this allows us to describe a changing ELA to mimic with an advance (to the little ice age), followed by a retreat as the one observed since the end of the little ice age (LIA).
#
# Let's now look at the results, vizualizing the time evolution of the glacier :

# %%
import importlib
import helper
importlib.reload(helper)
from helper import *
import glob

# Find all output files
output_files = sorted(glob.glob('outputs/*/*/output.nc'))

if output_files:
    print(f"Found {len(output_files)} output file(s). Using: {output_files[-1]}\n")
    # Visualize ice thickness evolution with sample locations
    animate_glacier_evolution(output_files[-1], variable='thk', log_scale=False, show_samples=True)
elif os.path.exists('output.nc'):
    print("Using output.nc in current directory\n")
    animate_glacier_evolution('output.nc', variable='thk', log_scale=False, show_samples=True)
else:
    print("No output.nc files found. Please run the model first.")
# Out:
# Found 3 output file(s). Using: outputs/2025-12-02/10-04-50/output.nc
# /content/glamod/04_notebook/helper.py:185: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.92, 0.96])

# %% [markdown]
# ## Analyzing the Time Series Results
#
# Let's examine how the glacier evolved under the climate scenario:

# %%
from helper import analyze_time_series
import glob

# Find time series files
ts_files = sorted(glob.glob('outputs/*/*/output_ts.nc'))

if ts_files:
    print(f"Found {len(ts_files)} time series file(s). Using: {ts_files[-1]}\n")
    analyze_time_series(ts_files[-1])
elif os.path.exists('output_ts.nc'):
    analyze_time_series('output_ts.nc')
else:
    print("No output_ts.nc file found.")
# Out:
# Found 2 time series file(s). Using: outputs/2025-12-02/09-02-22/output_ts.nc
#
# Reading time series data from: outputs/2025-12-02/09-02-22/output_ts.nc
# ============================================================
# SUMMARY STATISTICS
# ============================================================
#
# Ice Volume:
#   Initial: 0.79 km³
#   Final:   1.15 km³
#   Change:  0.35 km³
#
# Ice Area:
#   Initial: 10.53 km²
#   Final:   10.33 km²
#   Change:  -0.20 km²
# ============================================================

# %% [markdown]
# ## Glacier Velocity Evolution
#
# Now let's visualize the ice velocity magnitude evolution in log scale. This shows the flow dynamics and where the glacier is moving fastest.

# %%
from helper import animate_glacier_evolution
import glob

# Find all output files
output_files = sorted(glob.glob('outputs/*/*/output.nc'))

if output_files:
    print(f"Found {len(output_files)} output file(s). Using: {output_files[-1]}\n")
    # Visualize velocity evolution with sample locations
    animate_glacier_evolution(output_files[-1], variable='velbar_mag', log_scale=True, show_samples=True)
elif os.path.exists('output.nc'):
    print("Using output.nc in current directory\n")
    animate_glacier_evolution('output.nc', variable='velbar_mag', log_scale=True, show_samples=True)
else:
    print("No output.nc files found. Please run the model first.")
# Out:
# Found 2 output file(s). Using: outputs/2025-12-02/09-02-22/output.nc
# /content/glamod/04_notebook/helper.py:185: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.92, 0.96])

# %% [markdown]
# Now, we can visualize the time evolution of the modelled ice thickness at the location of each samples using the following plot.

# %%
from helper import *
import glob

# Find all output files
output_files = sorted(glob.glob('outputs/*/*/output.nc'))

if output_files:
    print(f"Found {len(output_files)} output file(s). Using: {output_files[-1]}\n")
    plot_thk_at_sample(output_files[-1])
elif os.path.exists('output.nc'):
    print("Using output.nc in current directory\n")
    plot_thk_at_sample('output.nc')
else:
    print("No output.nc files found. Please run the model first.")
# Out:
# Found 2 output file(s). Using: outputs/2025-12-02/09-02-22/output.nc

# %% [markdown]
# Modify the parameters in `yaml.json` as follows (tips: you may use a copy -- e.g. `params_0.yaml` -- to keep experimenting without losing the original setup):
#
# - Change the SMB parameters: initially adjust the ELA values over time, and later consider modifying the mass balance gradients and maximum accumulation values.
# - Set the parameter "iflo_init_slidingco" to a higher value (e.g., 0.4 for less basal sliding) and a lower value (e.g., 0.1 for more basal sliding).
#
# After making these changes, observe how they affect the glacier, and attempt to align the model (by changing iteratively parameters) with the ages of the collected samples.

# %% [markdown]
# ## To go further : using a **true** Surface Mass Balance Model
#
# As we did in notebook 2, you may replace the simple Surface Mass Balance (SMB) model with an improved model known as the [Positive Degree Day Model (PDD)](https://www.antarcticglaciers.org/glaciers-and-climate/numerical-ice-sheet-models/modelling-glacier-melt/).
